# %%
from nltk.stem import PorterStemmer

# %%
words = [
    "run", "running", "runs", "runner",
    "swim", "swimming", "swims", "swimmer",
    "play", "playing", "plays", "played",
    "study", "studying", "studies", "studied",
    "compute", "computing", "computes", "computed",
    "error", "errors", "erroneous", "erroring",
    "logic", "logical", "logics", "logically",
    "connect", "connection", "connects", "connected",
    "develop", "development", "developer", "developing",
    "analyze", "analysis", "analyzing", "analyzed",
    "logics", "logicals",  # Incorrect form
]

# %%
portstemmer = PorterStemmer()

for word in words:
    print(word, "------->", portstemmer.stem(word))
# Out:
# run -------> run
# running -------> run
# runs -------> run
# runner -------> runner
# swim -------> swim
# swimming -------> swim
# swims -------> swim
# swimmer -------> swimmer
# play -------> play
# playing -------> play
# plays -------> play
# played -------> play
# study -------> studi
# studying -------> studi
# studies -------> studi
# studied -------> studi
# compute -------> comput
# computing -------> comput
# computes -------> comput
# computed -------> comput
# error -------> error
# errors -------> error
# erroneous -------> erron
# erroring -------> error
# logic -------> logic
# logical -------> logic
# logics -------> logic
# logically -------> logic
# connect -------> connect
# connection -------> connect
# connects -------> connect
# connected -------> connect
# develop -------> develop
# development -------> develop
# developer -------> develop
# developing -------> develop
# analyze -------> analyz
# analysis -------> analysi
# analyzing -------> analyz
# ...

# %%
## RegexStemmer
from nltk.stem import RegexpStemmer

regrexstemmer = RegexpStemmer("s$/ed$/able$", min=4)
for word in words:
    print(word, "------->", regrexstemmer.stem(word))
# Out:
# run -------> run
# running -------> running
# runs -------> runs
# runner -------> runner
# swim -------> swim
# swimming -------> swimming
# swims -------> swims
# swimmer -------> swimmer
# play -------> play
# playing -------> playing
# plays -------> plays
# played -------> played
# study -------> study
# studying -------> studying
# studies -------> studies
# studied -------> studied
# compute -------> compute
# computing -------> computing
# computes -------> computes
# computed -------> computed
# error -------> error
# errors -------> errors
# erroneous -------> erroneous
# erroring -------> erroring
# logic -------> logic
# logical -------> logical
# logics -------> logics
# logically -------> logically
# connect -------> connect
# connection -------> connection
# connects -------> connects
# connected -------> connected
# develop -------> develop
# development -------> development
# developer -------> developer
# developing -------> developing
# analyze -------> analyze
# ...

# %%
## snowball stemmer
from nltk.stem import SnowballStemmer

snowballstemmer = SnowballStemmer('english')

for word in words:
    print(word, "----->", snowballstemmer.stem(word))
# Out:
# run -----> run
# running -----> run
# runs -----> run
# runner -----> runner
# swim -----> swim
# swimming -----> swim
# swims -----> swim
# swimmer -----> swimmer
# play -----> play
# playing -----> play
# plays -----> play
# played -----> play
# study -----> studi
# studying -----> studi
# studies -----> studi
# studied -----> studi
# compute -----> comput
# computing -----> comput
# computes -----> comput
# computed -----> comput
# error -----> error
# errors -----> error
# erroneous -----> erron
# erroring -----> error
# logic -----> logic
# logical -----> logic
# logics -----> logic
# logically -----> logic
# connect -----> connect
# connection -----> connect
# connects -----> connect
# connected -----> connect
# develop -----> develop
# development -----> develop
# developer -----> develop
# developing -----> develop
# analyze -----> analyz
# analysis -----> analysi
# analyzing -----> analyz
# analyzed -----> analyz
# logics -----> logic
# logicals -----> logic

# %%
## difference between portable stemmer and snowball stemmer
portstemmer.stem("fairly"), portstemmer.stem("sportingly")
# Out:
# ('fairli', 'sportingli')

# %%
# snowball stemmer gives the accurate words than portable stemmer
snowballstemmer.stem("fairly"), snowballstemmer.stem("sportingly")
# Out:
# ('fair', 'sport')

# %%
paragraph = """India is a vast country known for its diverse culture, rich history, and rapid development. It has many languages, religions, and traditions, making it unique. India's economy is growing quickly, with advancements in technology, education, and industries. The nation is home to iconic landmarks like the Taj Mahal and historical sites that reflect its heritage. Agriculture, manufacturing, and services play a significant role in its economy, while its population contributes to a dynamic workforce. Stemming in NLP can break words like "developing" into "develop," helping analyze texts about India's progress efficiently."""

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pavan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
sentences = nltk.sent_tokenize(paragraph)
sentences
# Out:
# ['India is a vast country known for its diverse culture, rich history, and rapid development.',
#  'It has many languages, religions, and traditions, making it unique.',
#  "India's economy is growing quickly, with advancements in technology, education, and industries.",
#  'The nation is home to iconic landmarks like the Taj Mahal and historical sites that reflect its heritage.',
#  'Agriculture, manufacturing, and services play a significant role in its economy, while its population contributes to a dynamic workforce.',
#  'Stemming in NLP can break words like "developing" into "develop," helping analyze texts about India\'s progress efficiently.']

# %%
words = nltk.word_tokenize(paragraph)
words
# Out:
# ['India',
#  'is',
#  'a',
#  'vast',
#  'country',
#  'known',
#  'for',
#  'its',
#  'diverse',
#  'culture',
#  ',',
#  'rich',
#  'history',
#  ',',
#  'and',
#  'rapid',
#  'development',
#  '.',
#  'It',
#  'has',
#  'many',
#  'languages',
#  ',',
#  'religions',
#  ',',
#  'and',
#  'traditions',
#  ',',
#  'making',
#  'it',
#  'unique',
#  '.',
#  'India',
#  "'s",
#  'economy',
#  'is',
#  'growing',
#  'quickly',
#  ',',
#  'with',
#  'advancements',
#  'in',
#  'technology',
#  ',',
#  'education',
#  ',',
#  'and',
#  'industries',
#  '.',
#  'The',
#  'nation',
#  'is',
#  'home',
#  'to',
#  'iconic',
#  'landmarks',
#  'like',
#  'the',
#  'Taj',
#  'Mahal',
#  'and',
#  'historical',
#  'sites',
#  'that',
#  'reflect',
#  'its',
#  'heritage',
#  '.',
#  'Agriculture',
#  ',',
#  'manufacturing',
#  ',',
#  'and',
#  'services',
#  'play',
#  'a',
#  'significant',
#  'role',
#  'in',
#  'its',
#  'economy',
#  ',',
#  'while',
#  'its',
#  'population',
# ...

# %%
### stemming
nltk.download('stopwords')
stop_words = stopwords.words('english')
stop_words
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\pavan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
# ...

# %%
##stemming
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

sentences = nltk.sent_tokenize(paragraph)
stem_sentences = list()
for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [stemmer.stem(word) for word in words if word not in stop_words]
    stem_sentences.append(" ".join(words))  # Join words back into a sentence

print(sentences)
print(stem_sentences)
# Out:
# ['India is a vast country known for its diverse culture, rich history, and rapid development.', 'It has many languages, religions, and traditions, making it unique.', "India's economy is growing quickly, with advancements in technology, education, and industries.", 'The nation is home to iconic landmarks like the Taj Mahal and historical sites that reflect its heritage.', 'Agriculture, manufacturing, and services play a significant role in its economy, while its population contributes to a dynamic workforce.', 'Stemming in NLP can break words like "developing" into "develop," helping analyze texts about India\'s progress efficiently.']
# ...

# %%
## lemmatization
from nltk.stem import WordNetLemmatizer

nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()

sentences = nltk.sent_tokenize(paragraph)
lemmatizer_sentences = list()
for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words]
    lemmatizer_sentences.append(" ".join(words))  # Join words back into a sentence

print(sentences)
print(lemmatizer_sentences)
# Out:
# ['India is a vast country known for its diverse culture, rich history, and rapid development.', 'It has many languages, religions, and traditions, making it unique.', "India's economy is growing quickly, with advancements in technology, education, and industries.", 'The nation is home to iconic landmarks like the Taj Mahal and historical sites that reflect its heritage.', 'Agriculture, manufacturing, and services play a significant role in its economy, while its population contributes to a dynamic workforce.', 'Stemming in NLP can break words like "developing" into "develop," helping analyze texts about India\'s progress efficiently.']
# ...
